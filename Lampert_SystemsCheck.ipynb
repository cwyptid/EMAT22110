# %% [markdown]
# # Welcome to my Jupyter Notebook!
# ## I know how to use different types of headings, like this!
# ### And this!

# %% [markdown]
# In this class i hope to learn:
#   1. Basics of coding in python (of course)
#   2. How to utilize and analyze different types of data
#   3. Work with data visualization
#   4. Get better with SVN or git!

# %% [markdown]
# <div class="alert alert-block alert-info">
# Look at me! I figured how out to make boxes blue.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# And yellow!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# Wow, they have green here too!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# Looks like red is the last color available!
# </div>

# %% [markdown]
# ![tumblr_79a4528b360765b4a4e4a1c34806e0cb_a1a57ead_1280.jpg](attachment:tumblr_79a4528b360765b4a4e4a1c34806e0cb_a1a57ead_1280.jpg)

# %% [markdown]
# This is a picture of a <b>very</b> cute monkey. I think it might be the monkey from <i>Mother 3</i> if you have played it, but I am not sure.
#
# You better watch out, 'cus now I am going to flex my (very minimal) Python knowledge!

# %% [markdown]
# <b>Variable Assignment</b>

# %%
myName = "Eddie Lampert"

# %% [markdown]
# <b>Basic Loop</b>

# %%
myArray = ["I", "Love", "Python"]
for x in myArray:
  print(x)
# Out:
# I
# Love
# Python

# %% [markdown]
# <b>Print Statement</b>

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# <b>Return Statement</b>

# %%
myName = "Eddie Lampert!"

def myFunction():
    return myName

print('My name is...')
print(myFunction())
# Out:
# My name is...
# Eddie Lampert!
